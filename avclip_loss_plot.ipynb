# %%
import re
import matplotlib.pyplot as plt

def scrape_losses_from_lines(lines):
    pattern = r'segment_contrastive_loss:\s([\d.]+)\s+loss:\s([\d.]+)'
    segment_contrastive_losses = []

    for line in lines:
        match = re.search(pattern, line)
        if match:
            segment_contrastive_losses.append(float(match.group(1)))
    return segment_contrastive_losses

def plot_losses(losses_dict):
    plt.figure(figsize=(10, 6))

    for label, losses in losses_dict.items():
        epochs = range(1, len(losses) + 1)
        plt.plot(epochs, losses, label=label, marker='o')

    plt.xlabel('Epoch')
    plt.ylabel('Segment Contrastive Loss')
    plt.title('Train vs Eval Loss Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

def scrape_epoch_lines(file_path):
    train_pattern = r'^.*\| INFO \| Train Epoch: (\d+) \(Worker #0\).*'
    eval_pattern = r'^.*\| INFO \| Eval Epoch: (\d+) \(All workers\).*'

    train_lines = []
    eval_lines = []

    with open(file_path, 'r') as file:
        for line in file:
            if re.search(train_pattern, line):
                train_lines.append(line.strip())
            elif re.search(eval_pattern, line):
                eval_lines.append(line.strip())

    return train_lines, eval_lines

# Example usage
file_path = '/home/gnivedita/Synchformer/logs/sync/avclip_models/23-12-22T16-13-38/out.log'  # Replace with your log file path
train_lines, eval_lines = scrape_epoch_lines(file_path)

# Extract losses from the extracted lines
train_losses = scrape_losses_from_lines(train_lines)
eval_losses = scrape_losses_from_lines(eval_lines)

# Plot losses
losses_dict = {
    "Train Loss": train_losses,
    "Eval Loss": eval_losses
}

plot_losses(losses_dict)

# %%
import re
import matplotlib.pyplot as plt

def scrape_losses_from_lines(lines):
    pattern = r'segment_contrastive_loss:\s([\d.]+)\s+loss:\s([\d.]+)'
    segment_contrastive_losses = []

    for line in lines:
        match = re.search(pattern, line)
        if match:
            segment_contrastive_losses.append(float(match.group(1)))
    return segment_contrastive_losses

def plot_losses(losses_dict):
    plt.figure(figsize=(10, 6))

    for label, losses in losses_dict.items():
        epochs = range(1, len(losses) + 1)
        plt.plot(epochs, losses, label=label, marker='o')

    plt.xlabel('Epoch')
    plt.ylabel('Segment Contrastive Loss')
    plt.title('Train vs Eval Loss Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

def scrape_epoch_lines(file_path):
    train_pattern = r'^.*\| INFO \| Train Epoch: (\d+) \(Worker #0\).*'
    eval_pattern = r'^.*\| INFO \| Eval Epoch: (\d+) \(All workers\).*'

    train_lines = []
    eval_lines = []

    with open(file_path, 'r') as file:
        for line in file:
            if re.search(train_pattern, line):
                train_lines.append(line.strip())
            elif re.search(eval_pattern, line):
                eval_lines.append(line.strip())

    return train_lines, eval_lines

# Example usage
file_path = '/home/gnivedita/Synchformer/logs/sync/avclip_models/23-12-22T16-13-38/out.log'  # Replace with your log file path
train_lines, eval_lines = scrape_epoch_lines(file_path)

# Extract losses from the extracted lines
train_losses = scrape_losses_from_lines(train_lines)
eval_losses = scrape_losses_from_lines(eval_lines)

# Plot losses
losses_dict = {
    "Train Loss": train_losses,
    "Eval Loss": eval_losses
}

plot_losses(losses_dict)

# %%
import re
import matplotlib.pyplot as plt

def scrape_losses_from_lines(lines):
    pattern = r'segment_contrastive_loss:\s([\d.]+)\s+loss:\s([\d.]+)'
    segment_contrastive_losses = []

    for line in lines:
        match = re.search(pattern, line)
        if match:
            segment_contrastive_losses.append(float(match.group(1)))
    return segment_contrastive_losses

def plot_losses(losses_dict):
    plt.figure(figsize=(10, 6))

    for label, losses in losses_dict.items():
        epochs = range(1, len(losses) + 1)
        plt.plot(epochs, losses, label=label, marker='o')

    plt.xlabel('Epoch')
    plt.ylabel('Segment Contrastive Loss')
    plt.title('Train vs Eval Loss Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

def scrape_epoch_lines(file_path):
    train_pattern = r'^.*\| INFO \| Train Epoch: (\d+) \(Worker #0\).*'
    eval_pattern = r'^.*\| INFO \| Eval Epoch: (\d+) \(All workers\).*'

    train_lines = []
    eval_lines = []

    with open(file_path, 'r') as file:
        for line in file:
            if re.search(train_pattern, line):
                train_lines.append(line.strip())
            elif re.search(eval_pattern, line):
                eval_lines.append(line.strip())

    return train_lines, eval_lines
print("learning rate = 0.00001")
# Example usage
file_path = '/home/gnivedita/Synchformer/logs/sync/avclip_models/23-12-22T16-13-38/out.log'  # Replace with your log file path
train_lines, eval_lines = scrape_epoch_lines(file_path)

# Extract losses from the extracted lines
train_losses = scrape_losses_from_lines(train_lines)
eval_losses = scrape_losses_from_lines(eval_lines)

# Plot losses
losses_dict = {
    "Train Loss": train_losses,
    "Eval Loss": eval_losses
}

plot_losses(losses_dict)
# Out:
# learning rate = 0.00001

# %%
#/home/gnivedita/Synchformer/logs/avclip_models/23-12-22T16-13-38/out.log
import re
import matplotlib.pyplot as plt

def scrape_losses_from_lines(lines):
    pattern = r'segment_contrastive_loss:\s([\d.]+)\s+loss:\s([\d.]+)'
    segment_contrastive_losses = []

    for line in lines:
        match = re.search(pattern, line)
        if match:
            segment_contrastive_losses.append(float(match.group(1)))
    return segment_contrastive_losses

def plot_losses(losses_dict):
    plt.figure(figsize=(10, 6))

    for label, losses in losses_dict.items():
        epochs = range(1, len(losses) + 1)
        plt.plot(epochs, losses, label=label, marker='o')

    plt.xlabel('Epoch')
    plt.ylabel('Segment Contrastive Loss')
    plt.title('Train vs Eval Loss Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

def scrape_epoch_lines(file_path):
    train_pattern = r'^.*\| INFO \| Train Epoch: (\d+) \(Worker #0\).*'
    eval_pattern = r'^.*\| INFO \| Eval Epoch: (\d+) \(All workers\).*'

    train_lines = []
    eval_lines = []

    with open(file_path, 'r') as file:
        for line in file:
            if re.search(train_pattern, line):
                train_lines.append(line.strip())
            elif re.search(eval_pattern, line):
                eval_lines.append(line.strip())

    return train_lines, eval_lines
print("learning rate = 0.0001")
# Example usage
file_path = '/home/gnivedita/Synchformer/logs/avclip_models/23-12-22T16-13-38/out.log'  # Replace with your log file path
train_lines, eval_lines = scrape_epoch_lines(file_path)

# Extract losses from the extracted lines
train_losses = scrape_losses_from_lines(train_lines)
eval_losses = scrape_losses_from_lines(eval_lines)

# Plot losses
losses_dict = {
    "Train Loss": train_losses,
    "Eval Loss": eval_losses
}

plot_losses(losses_dict)
# Out:
# learning rate = 0.0001

# %%
#/home/gnivedita/Synchformer/logs/avclip_models/23-12-22T16-13-38/out.log
import re
import matplotlib.pyplot as plt

def scrape_losses_from_lines(lines):
    pattern = r'segment_contrastive_loss:\s([\d.]+)\s+loss:\s([\d.]+)'
    segment_contrastive_losses = []

    for line in lines:
        match = re.search(pattern, line)
        if match:
            segment_contrastive_losses.append(float(match.group(1)))
    return segment_contrastive_losses

def plot_losses(losses_dict):
    plt.figure(figsize=(10, 6))

    for label, losses in losses_dict.items():
        epochs = range(1, len(losses) + 1)
        plt.plot(epochs, losses, label=label, marker='o')

    plt.xlabel('Epoch')
    plt.ylabel('Segment Contrastive Loss')
    plt.title('Train vs Eval Loss Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

def scrape_epoch_lines(file_path):
    train_pattern = r'^.*\| INFO \| Train Epoch: (\d+) \(Worker #0\).*'
    eval_pattern = r'^.*\| INFO \| Eval Epoch: (\d+) \(All workers\).*'

    train_lines = []
    eval_lines = []

    with open(file_path, 'r') as file:
        for line in file:
            if re.search(train_pattern, line):
                train_lines.append(line.strip())
            elif re.search(eval_pattern, line):
                eval_lines.append(line.strip())

    return train_lines, eval_lines
print("learning rate = 0.000001")
# Example usage
file_path = '/home/gnivedita/Synchformer/logs/avclip_models1/23-12-22T16-13-38/out.log'  # Replace with your log file path
train_lines, eval_lines = scrape_epoch_lines(file_path)

# Extract losses from the extracted lines
train_losses = scrape_losses_from_lines(train_lines)
eval_losses = scrape_losses_from_lines(eval_lines)

# Plot losses
losses_dict = {
    "Train Loss": train_losses,
    "Eval Loss": eval_losses
}

plot_losses(losses_dict)
# Out:
# learning rate = 0.000001

# %%
#/home/gnivedita/Synchformer/logs/avclip_vgg2/23-12-22T16-10-50/out.log

import re
import matplotlib.pyplot as plt

def scrape_losses_from_lines(lines):
    pattern = r'segment_contrastive_loss:\s([\d.]+)\s+loss:\s([\d.]+)'
    segment_contrastive_losses = []

    for line in lines:
        match = re.search(pattern, line)
        if match:
            segment_contrastive_losses.append(float(match.group(1)))
    return segment_contrastive_losses

def plot_losses(losses_dict):
    plt.figure(figsize=(10, 6))

    for label, losses in losses_dict.items():
        epochs = range(1, len(losses) + 1)
        plt.plot(epochs, losses, label=label, marker='o')

    plt.xlabel('Epoch')
    plt.ylabel('Segment Contrastive Loss')
    plt.title('Train vs Eval Loss Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

def scrape_epoch_lines(file_path):
    train_pattern = r'^.*\| INFO \| Train Epoch: (\d+) \(Worker #0\).*'
    eval_pattern = r'^.*\| INFO \| Eval Epoch: (\d+) \(All workers\).*'

    train_lines = []
    eval_lines = []

    with open(file_path, 'r') as file:
        for line in file:
            if re.search(train_pattern, line):
                train_lines.append(line.strip())
            elif re.search(eval_pattern, line):
                eval_lines.append(line.strip())

    return train_lines, eval_lines
print("learning rate = 0.0001")
# Example usage
file_path = '/home/gnivedita/Synchformer/logs/avclip_vgg2/23-12-22T16-10-50/out.log'  # Replace with your log file path
train_lines, eval_lines = scrape_epoch_lines(file_path)

# Extract losses from the extracted lines
train_losses = scrape_losses_from_lines(train_lines)
eval_losses = scrape_losses_from_lines(eval_lines)

# Plot losses
losses_dict = {
    "Train Loss": train_losses,
    "Eval Loss": eval_losses
}

plot_losses(losses_dict)
# Out:
# learning rate = 0.000001

# %%
#/home/gnivedita/Synchformer/logs/avclip_vgg2/23-12-22T16-10-50/out.log

import re
import matplotlib.pyplot as plt

def scrape_losses_from_lines(lines):
    pattern = r'segment_contrastive_loss:\s([\d.]+)\s+loss:\s([\d.]+)'
    segment_contrastive_losses = []

    for line in lines:
        match = re.search(pattern, line)
        if match:
            segment_contrastive_losses.append(float(match.group(1)))
    return segment_contrastive_losses

def plot_losses(losses_dict):
    plt.figure(figsize=(10, 6))

    for label, losses in losses_dict.items():
        epochs = range(1, len(losses) + 1)
        plt.plot(epochs, losses, label=label, marker='o')

    plt.xlabel('Epoch')
    plt.ylabel('Segment Contrastive Loss')
    plt.title('Train vs Eval Loss Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

def scrape_epoch_lines(file_path):
    train_pattern = r'^.*\| INFO \| Train Epoch: (\d+) \(Worker #0\).*'
    eval_pattern = r'^.*\| INFO \| Eval Epoch: (\d+) \(All workers\).*'

    train_lines = []
    eval_lines = []

    with open(file_path, 'r') as file:
        for line in file:
            if re.search(train_pattern, line):
                train_lines.append(line.strip())
            elif re.search(eval_pattern, line):
                eval_lines.append(line.strip())

    return train_lines, eval_lines
print("learning rate = 0.0001, tou = 0.01")
# Example usage
file_path = '/home/gnivedita/Synchformer/logs/avclip_models/23-12-22T16-13-38/out.log'  # Replace with your log file path
train_lines, eval_lines = scrape_epoch_lines(file_path)

# Extract losses from the extracted lines
train_losses = scrape_losses_from_lines(train_lines)
eval_losses = scrape_losses_from_lines(eval_lines)

# Plot losses
losses_dict = {
    "Train Loss": train_losses,
    "Eval Loss": eval_losses
}

plot_losses(losses_dict)
# Out:
# learning rate = 0.0001, tou = 0.01
