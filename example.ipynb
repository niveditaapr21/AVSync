# %% [markdown]
# # Synchformer: Efficient Synchronization from Sparse Cues
#
# <figure>
#   <img src="https://github.com/v-iashin/Synchformer/raw/main/_repo_assets/main.png" width="700" />
# </figure>
#
# This notebook demonstrates a minimal working example of audio-visual synchronisation on a sample video with a sparse synchronisation signal.
#
# [Project Page](https://www.robots.ox.ac.uk/~vgg/research/synchformer/) | [Code & Models](https://github.com/v-iashin/Synchformer)

# %% [markdown]
# Uncomment the lines in the following cell if you are on Google Colab

# %%
# !git clone https://github.com/v-iashin/Synchformer.git
# !pip install omegaconf==2.0.6 av==10.0 einops timm==0.6.12
# %cd Synchformer

# %%
import subprocess
from pathlib import Path

import torch
import torchaudio
import torchvision
from omegaconf import OmegaConf

from dataset.dataset_utils import get_video_and_audio
from dataset.transforms import make_class_grid, quantize_offset
from utils.utils import check_if_file_exists_else_download, which_ffmpeg
from scripts.train_utils import get_model, get_transforms, prepare_inputs


def reencode_video(path, vfps=25, afps=16000, in_size=256):
    assert which_ffmpeg() != '', 'Is ffmpeg installed? Check if the conda environment is activated.'
    new_path = Path.cwd() / 'vis' / f'{Path(path).stem}_{vfps}fps_{in_size}side_{afps}hz.mp4'
    new_path.parent.mkdir(exist_ok=True)
    new_path = str(new_path)
    cmd = f'{which_ffmpeg()}'
    # no info/error printing
    cmd += ' -hide_banner -loglevel panic'
    cmd += f' -y -i {path}'
    # 1) change fps, 2) resize: min(H,W)=MIN_SIDE (vertical vids are supported), 3) change audio framerate
    cmd += f" -vf fps={vfps},scale=iw*{in_size}/'min(iw,ih)':ih*{in_size}/'min(iw,ih)',crop='trunc(iw/2)'*2:'trunc(ih/2)'*2"
    cmd += f" -ar {afps}"
    cmd += f' {new_path}'
    subprocess.call(cmd.split())
    cmd = f'{which_ffmpeg()}'
    cmd += ' -hide_banner -loglevel panic'
    cmd += f' -y -i {new_path}'
    cmd += f' -acodec pcm_s16le -ac 1'
    cmd += f' {new_path.replace(".mp4", ".wav")}'
    subprocess.call(cmd.split())
    return new_path


def decode_single_video_prediction(off_logits, grid, item):
    label = item['targets']['offset_label'].item()
    print('Ground Truth offset (sec):', f'{label:.2f} ({quantize_offset(grid, label)[-1].item()})')
    print('Prediction Results:')
    off_probs = torch.softmax(off_logits, dim=-1)

    filename = "./result.csv"
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    offsets = torch.arange(-2,2.1,0.2).to(device).half()   
    offset_prediction = torch.dot(off_probs.squeeze(), offsets)
    with open(filename, 'a') as f:
        f.write(f"{offset_prediction:.4f},")
        
    k = min(off_probs.shape[-1], 5)
    topk_logits, topk_preds = torch.topk(off_logits, k)
    # remove batch dimension
    assert len(topk_logits) == 1, 'batch is larger than 1'
    topk_logits = topk_logits[0]
    topk_preds = topk_preds[0]
    off_logits = off_logits[0]
    off_probs = off_probs[0]
    temp = 0
    for target_hat in topk_preds:
        print(
            f'p={off_probs[target_hat]:.4f} ({off_logits[target_hat]:.4f}), "{grid[target_hat]:.2f}" ({target_hat})')
        if temp == 0:
            temp = 1
            with open(filename, 'a') as f:
                #f.write(f"{off_probs[target_hat]:.4f},({off_logits[target_hat]:.4f}),{grid[target_hat]:.2f},({target_hat})\n")     
                f.write(f"{off_probs[target_hat]:.4f},({off_logits[target_hat]:.4f}),{grid[target_hat]:.2f},({target_hat})\n")  
    return off_probs


def patch_config(cfg):
    # the FE ckpts are already in the model ckpt
    cfg.model.params.afeat_extractor.params.ckpt_path = None
    cfg.model.params.vfeat_extractor.params.ckpt_path = None
    # old checkpoints have different names
    cfg.model.params.transformer.target = cfg.model.params.transformer.target\
                                             .replace('.modules.feature_selector.', '.sync_model.')
    return cfg

# %%
vfps = 25
afps = 16000
in_size = 256
exp_name = '24-01-04T16-39-21'

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# load the model
cfg_path = f'./logs/sync_models/{exp_name}/cfg-{exp_name}.yaml'
ckpt_path = f'./logs/sync_models/{exp_name}/{exp_name}.pt'

# if the model does not exist try to download it from the server
check_if_file_exists_else_download(cfg_path)
check_if_file_exists_else_download(ckpt_path)

# load config
cfg = OmegaConf.load(cfg_path)

# patch config
cfg = patch_config(cfg)

_, model = get_model(cfg, device)
ckpt = torch.load(ckpt_path, map_location=torch.device('cpu'))
model.load_state_dict(ckpt['model'])
model.eval()
print('Model loaded.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 19
#      17 _, model = get_model(cfg, device)
#      18 ckpt = torch.load(ckpt_path, map_location=torch.device('cpu'))
# ---> 19 model.load_state_dict(ckpt['model'])
#      20 model.eval()
#      21 print('Model loaded.')
#
# File ~/Synchformer/model/sync_model.py:114, in Synchformer.load_state_dict(self, sd, strict)
#     112     elif weight_len < self_len:
#     113         raise ValueError(f'Cant load state dict with shorter seq len ({weight_len} vs {self_len})')
# --> 114 return super().load_state_dict(sd, strict)
#
# File ~/anaconda3/envs/synchformer/lib/python3.8/site-packages/torch/nn/modules/module.py:2027, in Module.load_state_dict(self, state_dict, strict)
#    2020         out = hook(module, incompatible_keys)
#    2021         assert out is None, (
#    2022             "Hooks registered with ``register_load_state_dict_post_hook`` are not"
#    2023             "expected to return new values, if incompatible_keys need to be modified,"
#    2024             "it should be done inplace."
#    2025         )
# -> 2027 load(self, state_dict)
#    2028 del load
#    2030 if strict:
#
# File ~/anaconda3/envs/synchformer/lib/python3.8/site-packages/torch/nn/modules/module.py:2015, in Module.load_state_dict.<locals>.load(module, local_state_dict, prefix)
#    2013         child_prefix = prefix + name + '.'
#    2014         child_state_dict = {k: v for k, v in local_state_dict.items() if k.startswith(child_prefix)}
# -> 2015         load(child, child_state_dict, child_prefix)
#    2017 # Note that the hook can modify missing_keys and unexpected_keys.
#    2018 incompatible_keys = _IncompatibleKeys(missing_keys, unexpected_keys)
#
# File ~/anaconda3/envs/synchformer/lib/python3.8/site-packages/torch/nn/modules/module.py:2015, in Module.load_state_dict.<locals>.load(module, local_state_dict, prefix)
#    2013         child_prefix = prefix + name + '.'
#    2014         child_state_dict = {k: v for k, v in local_state_dict.items() if k.startswith(child_prefix)}
# -> 2015         load(child, child_state_dict, child_prefix)
#    2017 # Note that the hook can modify missing_keys and unexpected_keys.
#    2018 incompatible_keys = _IncompatibleKeys(missing_keys, unexpected_keys)
#
#     [... skipping similar frames: Module.load_state_dict.<locals>.load at line 2015 (4 times)]
#
# File ~/anaconda3/envs/synchformer/lib/python3.8/site-packages/torch/nn/modules/module.py:2015, in Module.load_state_dict.<locals>.load(module, local_state_dict, prefix)
#    2013         child_prefix = prefix + name + '.'
#    2014         child_state_dict = {k: v for k, v in local_state_dict.items() if k.startswith(child_prefix)}
# -> 2015         load(child, child_state_dict, child_prefix)
#    2017 # Note that the hook can modify missing_keys and unexpected_keys.
#    2018 incompatible_keys = _IncompatibleKeys(missing_keys, unexpected_keys)
#
# File ~/anaconda3/envs/synchformer/lib/python3.8/site-packages/torch/nn/modules/module.py:2009, in Module.load_state_dict.<locals>.load(module, local_state_dict, prefix)
#    2007 def load(module, local_state_dict, prefix=''):
#    2008     local_metadata = {} if metadata is None else metadata.get(prefix[:-1], {})
# -> 2009     module._load_from_state_dict(
#    2010         local_state_dict, prefix, local_metadata, True, missing_keys, unexpected_keys, error_msgs)
#    2011     for name, child in module._modules.items():
#    2012         if child is not None:
#
# File ~/anaconda3/envs/synchformer/lib/python3.8/site-packages/torch/nn/modules/module.py:1942, in Module._load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    1940 try:
#    1941     with torch.no_grad():
# -> 1942         param.copy_(input_param)
#    1943 except Exception as ex:
#    1944     error_msgs.append('While copying the parameter named "{}", '
#    1945                       'whose dimensions in the model are {} and '
#    1946                       'whose dimensions in the checkpoint are {}, '
#    1947                       'an exception occurred : {}.'
#    1948                       .format(key, param.size(), input_param.size(), ex.args))
#
# KeyboardInterrupt:

# %%
'''import os
import random
import pandas as pd
to_process = []
#x = '/home/gnivedita/Synchformer/data/vggsound/h264_video_25fps_256side_16000hz_aac'
x = '/home/gnivedita/Wav2Lip/videos/LRS2_shifted_LGset2offset'
for file in os.listdir(x):
    if file.endswith(".mp4"):
        #v_start_sec = round(random.uniform(2, 3), 2)
        #print(float(file[:-4].split('_')[-1]))      
        #audioset
        audioset_df = pd.read_csv("v_start_sec.csv")
        if file[:-4] in audioset_df['vidname'].values:
            pass
            # Get the corresponding v_start_sec
            # v_start_sec = audioset_df.loc[audioset_df['vidname'] == file[:-4], 'v_start_sec'].values[0]
            # print(file, v_start_sec)
        else:
            #lrs2
            if float(file[:-4].split('_')[-1]) == 2:
                continue
            elif float(file[:-4].split('_')[-1]) > 0:
                v_start_sec = 0
            else:
                v_start_sec = 1
        # offset_in_sync = random.choice([-0.2, -0.1, 0, 0.1, 0.2])
        # offset_out_of_sync = random.choice([-1, -0.9, -0.8, -0.7, -0.6, -0.5, -0.4, -0.3, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1])
        # if offset_in_sync > 0:
        #     v_start_sec = 0
        # else: 
        #     v_start_sec = 1
        # to_process.append((x+'/'+file, offset_in_sync, v_start_sec))      
        # if offset_out_of_sync > 0:
        #     v_start_sec = 0
        # else: 
        #     v_start_sec = 1
        # to_process.append((x+'/'+file, offset_out_of_sync, v_start_sec))
        to_process.append((x+'/'+file, 0, v_start_sec))'''
# Out:
# 'import os\nimport random\nimport pandas as pd\nto_process = []\n#x = \'/home/gnivedita/Synchformer/data/vggsound/h264_video_25fps_256side_16000hz_aac\'\nx = \'/home/gnivedita/Wav2Lip/videos/LRS2_shifted_LGset2offset\'\nfor file in os.listdir(x):\n    if file.endswith(".mp4"):\n        #v_start_sec = round(random.uniform(2, 3), 2)\n        #print(float(file[:-4].split(\'_\')[-1]))      \n        #audioset\n        audioset_df = pd.read_csv("v_start_sec.csv")\n        if file[:-4] in audioset_df[\'vidname\'].values:\n            pass\n            # Get the corresponding v_start_sec\n            # v_start_sec = audioset_df.loc[audioset_df[\'vidname\'] == file[:-4], \'v_start_sec\'].values[0]\n            # print(file, v_start_sec)\n        else:\n            #lrs2\n            if float(file[:-4].split(\'_\')[-1]) == 2:\n                continue\n            elif float(file[:-4].split(\'_\')[-1]) > 0:\n                v_start_sec = 0\n            else:\n                v_start_sec = 1\n        # offset_in_sync = random.choice([-0.2, -0.1, 0, 0.1, 0.2])\n        # offset_out_of_sync = random.choice([-1, -0.9, -0.8, -0.7, -0.6, -0.5, -0.4, -0.3, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1])\n        # if offset_in_sync > 0:\n        #     v_start_sec = 0\n        # else: \n        #     v_start_sec = 1\n        # to_process.append((x+\'/\'+file, offset_in_sync, v_start_sec))      \n        # if offset_out_of_sync > 0:\n        #     v_start_sec = 0\n        # else: \n        #     v_start_sec = 1\n        # to_process.append((x+\'/\'+file, offset_out_of_sync, v_start_sec))\n        to_process.append((x+\'/\'+file, 0, v_start_sec))'

# %%
import os
import random
import pandas as pd
import numpy as np

x = '/home/gnivedita/Wav2Lip/videos/set2' 
# Load the CSV file
csv_path = '/home/gnivedita/Synchformer/data/vggsound.csv'  # Replace with the actual path to vggsound.csv
vggsound_data = pd.read_csv(csv_path)

# Extract column 1 values as a set for efficient lookup
file_names_in_csv = set(vggsound_data.iloc[:, 0])  # Assuming column 1 is the first column (0-based index)

# Initialize a list to process
to_process = []
#x = '/home/gnivedita/Synchformer/data_-0.2to0.2/vggsound/h264_video_25fps_256side_16000hz_aac'
# for training videos present in vggsound:
'''for file in os.listdir(x):
    if file.endswith((".mp4",".mov")):
        file_name_no_ext = os.path.splitext(file)[0]
        if file_name_no_ext in file_names_in_csv:
            v_start_sec = 0
            to_process.append((x+'/'+file, 0, v_start_sec))'''

for file in os.listdir(x):
    if file.endswith((".mp4",".mov")):
        v_start_sec = 0.5
        offset_sec = np.round(float(file.split('_')[-2]), 2)
        #offset_sec = 0
        to_process.append((x+'/'+file, offset_sec, v_start_sec))

# %%
print(len(to_process))
# Out:
# 530

# %%
'''# list of items to process. Mind the order: (video_path, offset_sec, v_start_i_sec)
to_process = [
    ('./data/vggsound/h264_video_25fps_256side_16000hz_aac/3qesirWAGt4_20000_30000.mp4', 1.6, 0.0),
    ('./data/vggsound/h264_video_25fps_256side_16000hz_aac/ZYc410CE4Rg_0_10000.mp4', -2.0, 4.0),
]'''
# Out:
# "# list of items to process. Mind the order: (video_path, offset_sec, v_start_i_sec)\nto_process = [\n    ('./data/vggsound/h264_video_25fps_256side_16000hz_aac/3qesirWAGt4_20000_30000.mp4', 1.6, 0.0),\n    ('./data/vggsound/h264_video_25fps_256side_16000hz_aac/ZYc410CE4Rg_0_10000.mp4', -2.0, 4.0),\n]"

# %%
for vid_path, offset_sec, v_start_i_sec in to_process:
    # (optional) checking if the provided video has the correct frame rates
    print(f'Using video: {vid_path}')
    with open("./result.csv", 'a') as f:
        f.write(f"{vid_path.split('/')[-1][:-4]},{v_start_i_sec},")

    v, _, info = torchvision.io.read_video(vid_path, pts_unit='sec')
    _, H, W, _ = v.shape
    if info['video_fps'] != vfps or info['audio_fps'] != afps or min(H, W) != in_size:
        print(f'Reencoding. vfps: {info["video_fps"]} -> {vfps};', end=' ')
        print(f'afps: {info["audio_fps"]} -> {afps};', end=' ')
        print(f'{(H, W)} -> min(H, W)={in_size}')
        vid_path = reencode_video(vid_path, vfps, afps, in_size)
    else:
        print(
            f'No need to reencode: vfps: {info["video_fps"]}; afps: {info["audio_fps"]}; min(H, W)={in_size}')

    # load visual and audio streams
    # rgb: (Tv, 3, H, W) in [0, 225], audio: (Ta,) in [-1, 1]
    try:
        rgb, audio, meta = get_video_and_audio(vid_path, get_meta=True)

    except Exception as e:
        # Print an error message and continue
        print(f"Skipping video: {vid_path} due to error: {e}")
        continue

    # making an item (dict) to apply transformations
    # NOTE: here is how it works:
    # For instance, if the model is trained on 5sec clips, the provided video is 9sec, and `v_start_i_sec=1.3`
    # the transform will crop out a 5sec-clip from 1.3 to 6.3 seconds and shift the start of the audio
    # track by `offset_sec` seconds. It means that if `offset_sec` > 0, the audio will
    # start by `offset_sec` earlier than the rgb track.
    # It is a good idea to use something in [-`max_off_sec`, `max_off_sec`] (-2, +2) seconds (see `grid`)
    item = dict(
        video=rgb, audio=audio, meta=meta, path=vid_path, split='test',
        targets={'v_start_i_sec': v_start_i_sec, 'offset_sec': offset_sec, },
    )
    print(f"offset_sec: {offset_sec}")
    # making the offset class grid similar to the one used in transforms
    max_off_sec = cfg.data.max_off_sec
    num_cls = cfg.model.params.transformer.params.off_head_cfg.params.out_features
    grid = make_class_grid(-max_off_sec, max_off_sec, num_cls)
    if not (min(grid) <= item['targets']['offset_sec'] <= max(grid)):
        print(f'WARNING: offset_sec={item["targets"]["offset_sec"]} is outside the trained grid: {grid}')

    # applying the test-time transform
    item = get_transforms(cfg, ['test'])['test'](item)

    # prepare inputs for inference
    batch = torch.utils.data.default_collate([item])
    aud, vid, targets = prepare_inputs(batch, device)

    # TODO:
    # sanity check: we will take the input to the `model` and recontruct make a video from it.
    # Use this check to make sure the input makes sense (audio should be ok but shifted as you specified)
    # reconstruct_video_from_input(aud, vid, batch['meta'], vid_path, v_start_i_sec, offset_sec,
    #                              vfps, afps)

    # forward pass
    with torch.set_grad_enabled(False):
        with torch.autocast('cuda', enabled=cfg.training.use_half_precision):
            _, logits = model(vid, aud)

    # simply prints the results of the prediction
    decode_single_video_prediction(logits, grid, item)
    print()
# Out:
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c13_sample2_0_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (234, 416) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2080 (7.1406), "0.08" (14)
# p=0.2048 (7.1250), "0.06" (13)
# p=0.1144 (6.5430), "0.10" (15)
# p=0.1096 (6.5000), "0.04" (12)
# p=0.0686 (6.0312), "0.20" (20)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c13_sample3_0_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (234, 416) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1881 (6.2383), "0.02" (11)
# p=0.1660 (6.1133), "0.00" (10)
# p=0.1471 (5.9922), "-0.02" (9)
# p=0.1350 (5.9062), "0.04" (12)
# p=0.1035 (5.6406), "-0.04" (8)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c13_sample4_0_4s.mp4
# Reencoding. vfps: 25.0 -> 25; afps: 44100 -> 16000; (432, 768) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1514 (5.5039), "-0.12" (4)
# p=0.1320 (5.3672), "-0.14" (3)
# p=0.1174 (5.2500), "-0.10" (5)
# p=0.1156 (5.2344), "-0.08" (6)
# p=0.0859 (4.9375), "-0.06" (7)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c13_sample5_0_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2214 (7.2617), "0.08" (14)
# p=0.2146 (7.2305), "0.10" (15)
# p=0.1698 (6.9961), "0.06" (13)
# p=0.1144 (6.6016), "0.12" (16)
# p=0.0901 (6.3633), "0.04" (12)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c14_sample1_0_4s.mp4
# Reencoding. vfps: 23.98 -> 25; afps: 44100 -> 16000; (432, 768) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1632 (7.1680), "0.08" (14)
# p=0.1613 (7.1562), "0.10" (15)
# p=0.1375 (6.9961), "0.12" (16)
# p=0.1130 (6.8008), "0.06" (13)
# p=0.1078 (6.7539), "0.14" (17)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c14_sample2_0_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (234, 416) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1816 (6.2734), "0.06" (13)
# p=0.1648 (6.1758), "0.08" (14)
# p=0.1622 (6.1602), "0.04" (12)
# p=0.0760 (5.4023), "0.02" (11)
# p=0.0757 (5.3984), "0.10" (15)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c14_sample3_0_4s.mp4
# Reencoding. vfps: 23.98 -> 25; afps: 44100 -> 16000; (432, 768) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.0969 (4.5742), "0.04" (12)
# p=0.0878 (4.4766), "0.10" (15)
# p=0.0869 (4.4648), "0.02" (11)
# p=0.0828 (4.4180), "0.00" (10)
# p=0.0760 (4.3320), "0.06" (13)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c14_sample4_0_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (234, 416) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1855 (6.9414), "0.06" (13)
# p=0.1855 (6.9414), "0.08" (14)
# p=0.1777 (6.8984), "0.10" (15)
# p=0.1265 (6.5586), "0.04" (12)
# p=0.0814 (6.1172), "0.02" (11)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample1_0_4s.mov
# Reencoding. vfps: 23.98 -> 25; afps: 44100 -> 16000; (234, 416) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2380 (5.7148), "0.04" (12)
# p=0.2372 (5.7109), "0.02" (11)
# p=0.1274 (5.0898), "0.06" (13)
# p=0.1044 (4.8906), "0.00" (10)
# p=0.0656 (4.4258), "-0.20" (0)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample2_0_4s.mov
# Reencoding. vfps: 23.98 -> 25; afps: 44100 -> 16000; (234, 416) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1870 (6.3125), "-0.04" (8)
# p=0.1855 (6.3047), "-0.02" (9)
# p=0.1497 (6.0898), "0.00" (10)
# p=0.1086 (5.7695), "-0.06" (7)
# p=0.0955 (5.6406), "0.02" (11)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample3_0_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1366 (5.9609), "-0.12" (4)
# p=0.1355 (5.9531), "-0.14" (3)
# p=0.1298 (5.9102), "-0.10" (5)
# p=0.1283 (5.8984), "-0.08" (6)
# p=0.0980 (5.6289), "-0.06" (7)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample4_0_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.
0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.3506 (7.1797), "0.06" (13)
# p=0.2896 (6.9883), "0.04" (12)
# p=0.1226 (6.1289), "0.02" (11)
# p=0.1129 (6.0469), "0.08" (14)
# p=0.0495 (5.2227), "0.10" (15)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c1_sample4_0_4s.mp4
# Reencoding. vfps: 25.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2112 (7.1719), "0.06" (13)
# p=0.1992 (7.1133), "0.08" (14)
# p=0.1521 (6.8438), "0.04" (12)
# p=0.1440 (6.7891), "0.10" (15)
# p=0.1002 (6.4258), "0.02" (11)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c1_sample5_0_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.3003 (7.0039), "-0.10" (5)
# p=0.2163 (6.6758), "-0.12" (4)
# p=0.1470 (6.2891), "-0.08" (6)
# p=0.1257 (6.1328), "-0.06" (7)
# p=0.0854 (5.7461), "-0.14" (3)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c1_sample6_0_4s.mp4
# Reencoding. vfps: 25.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2178 (4.9062), "0.06" (13)
# p=0.1364 (4.4375), "0.02" (11)
# p=0.1203 (4.3125), "0.00" (10)
# p=0.1021 (4.1484), "0.04" (12)
# p=0.0883 (4.0039), "0.12" (16)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c1_sample7_0_4s.mp4
# Reencoding. vfps: 25.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1693 (6.1992), "0.00" (10)
# p=0.1437 (6.0352), "0.04" (12)
# p=0.1283 (5.9219), "0.06" (13)
# p=0.1229 (5.8789), "0.02" (11)
# p=0.1132 (5.7969), "0.08" (14)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c2_sample1_0_4s.mov
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (360, 640) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2769 (7.0820), "0.04" (12)
# p=0.1956 (6.7344), "0.06" (13)
# p=0.1699 (6.5938), "0.02" (11)
# p=0.1398 (6.3984), "0.00" (10)
# p=0.0679 (5.6758), "-0.02" (9)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c2_sample2_0_4s.mov
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (360, 640) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.3130 (6.1758), "0.20" (20)
# p=0.1769 (5.6055), "0.18" (19)
# p=0.0865 (4.8906), "0.16" (18)
# p=0.0701 (4.6797), "0.14" (17)
# p=0.0537 (4.4141), "0.12" (16)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c2_sample3_0_4s.mp4
# Reencoding. vfps: 25.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.3354 (8.4062), "0.14" (17)
# p=0.1904 (7.8398), "0.18" (19)
# p=0.1754 (7.7578), "0.20" (20)
# p=0.1667 (7.7070), "0.12" (16)
# p=0.0531 (6.5625), "0.16" (18)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c3_sample1_0_4s.mp4
# Reencoding. vfps: 25.0 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1465 (6.0000), "-0.08" (6)
# p=0.1272 (5.8594), "-0.06" (7)
# p=0.1219 (5.8164), "-0.10" (5)
# p=0.1205 (5.8047), "-0.12" (4)
# p=0.1182 (5.7852), "-0.04" (8)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c4_sample1_0_4s.mov
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2317 (7.2109), "0.04" (12)
# p=0.2029 (7.0781), "0.06" (13)
# p=0.1763 (6.9375), "0.02" (11)
# p=0.1709 (6.9062), "0.00" (10)
# p=0.1032 (6.4023), "0.08" (14)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c5_sample1_0_4s.mov
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1406 (6.1641), "0.06" (13)
# p=0.1321 (6.1016), "0.04" (12)
# p=0.0922 (5.7422), "0.02" (11)
# p=0.0840 (5.6484), "0.08" (14)
# p=0.0680 (5.4375), "0.20" (20)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c5_sample2_0_4s.mp4
# Reencoding. vfps: 23.98 -> 25; afps: 44100 -> 16000; (234, 416) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.

#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c11_sample5_0_4s.mov
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2598 (7.4922), "0.14" (17)
# p=0.2062 (7.2617), "0.16" (18)
# p=0.1885 (7.1719), "0.18" (19)
# p=0.1261 (6.7695), "0.20" (20)
# p=0.1261 (6.7695), "0.12" (16)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c11_sample6_0_4s.mov
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.4871 (10.7344), "0.16" (18)
# p=0.3618 (10.4375), "0.18" (19)
# p=0.1021 (9.1719), "0.20" (20)
# p=0.0413 (8.2656), "0.14" (17)
# p=0.0054 (6.2383), "0.12" (16)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c11_sample7_0_4s.mov
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2081 (6.3242), "-0.02" (9)
# p=0.1665 (6.1016), "-0.04" (8)
# p=0.1639 (6.0859), "0.00" (10)
# p=0.1154 (5.7344), "-0.06" (7)
# p=0.0938 (5.5273), "0.02" (11)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c11_sample8_0_4s.mp4
# Reencoding. vfps: 25.0 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2053 (6.8750), "0.02" (11)
# p=0.2029 (6.8633), "0.04" (12)
# p=0.1763 (6.7227), "0.00" (10)
# p=0.1103 (6.2539), "0.06" (13)
# p=0.1065 (6.2188), "-0.02" (9)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c11_sample9_0_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2250 (7.1094), "0.10" (15)
# p=0.2064 (7.0234), "0.08" (14)
# p=0.1338 (6.5898), "0.06" (13)
# p=0.1233 (6.5078), "0.12" (16)
# p=0.0902 (6.1953), "0.14" (17)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c11_sample10_0_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2090 (7.2734), "-0.04" (8)
# p=0.1844 (7.1484), "-0.02" (9)
# p=0.1219 (6.7344), "0.00" (10)
# p=0.1205 (6.7227), "-0.06" (7)
# p=0.0942 (6.4766), "-0.08" (6)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c11_sample11_0_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.0932 (5.0156), "-0.04" (8)
# p=0.0883 (4.9609), "-0.12" (4)
# p=0.0819 (4.8867), "-0.08" (6)
# p=0.0803 (4.8672), "-0.02" (9)
# p=0.0749 (4.7969), "0.00" (10)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c12_sample1_0_4s.mov
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1689 (6.1484), "0.00" (10)
# p=0.1538 (6.0547), "-0.02" (9)
# p=0.1467 (6.0078), "0.02" (11)
# p=0.1368 (5.9375), "0.04" (12)
# p=0.1074 (5.6953), "-0.04" (8)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c12_sample2_0_4s.mov
# Reencoding. vfps: 23.98 -> 25; afps: 44100 -> 16000; (432, 768) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1571 (6.3320), "0.20" (20)
# p=0.1437 (6.2422), "0.18" (19)
# p=0.1063 (5.9414), "0.10" (15)
# p=0.0949 (5.8281), "0.12" (16)
# p=0.0942 (5.8203), "0.14" (17)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c12_sample3_0_4s.mov
# Reencoding. vfps: 23.98 -> 25; afps: 44100 -> 16000; (234, 416) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.2316 (6.4648), "0.10" (15)
# p=0.2280 (6.4492), "0.12" (16)
# p=0.0865 (5.4805), "0.00" (10)
# p=0.0734 (5.3164), "0.14" (17)
# p=0.0706 (5.2773), "-0.02" (9)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c12_sample4_0_4s.mp4
# Reencoding. vfps: 25.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.3367 (7.7344), "0.02" (11)
# p=0.3018 (7.6250), "0.00" (10)
# p=0.1980 (7.2031), "0.04" (12)
# p=0.0920 (6.4375), "0.06" (13)
# p=0.0216 (4.9883), "0.08" (14)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c13_sample1_0_4s.mov
# Reencoding. vfps: 50.0 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# nivi: 0.5, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.5
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.00 (10)
# Prediction Results:
# p=0.1201 (4.8633), "0.04" (12)
# p=0.1051 (4.7305), "0.06" (13)
# p=0.1027 (4.7070), "0.02" (11)
# p=0.0953 (4.6328), "0.08" (14)
# p=0.0793 (4.4492), "0.10" (15)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2h_c8_sample3_0_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (480, 640) -> min(H, W)=256
# offset_sec: 0.0
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.0 0.5
# here4:0.0
# nivi: 0.5
# nivi: 0.48
# ...
# nivi: 0.48
# nivi: 0.66, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.66
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.16 (18)
# Prediction Results:
# p=0.1355 (5.7734), "0.04" (12)
# p=0.1312 (5.7422), "0.02" (11)
# p=0.1229 (5.6758), "0.00" (10)
# p=0.1105 (5.5703), "-0.02" (9)
# p=0.1011 (5.4805), "0.06" (13)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample3_0.15_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.3
# WARNING: offset_sec=0.3 is outside the trained grid: tensor([-0.2000, -0.1800, -0.1600, -0.1400, -0.1200, -0.1000, -0.0800, -0.0600,
#         -0.0400, -0.0200,  0.0000,  0.0200,  0.0400,  0.0600,  0.0800,  0.1000,
#          0.1200,  0.1400,  0.1600,  0.1800,  0.2000])
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.3 0.5
# here4:0.3
# nivi: 0.8
# nivi: 0.48
# nivi: 0.8, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.8
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.20 (20)
# Prediction Results:
# p=0.1572 (6.2578), "0.06" (13)
# p=0.1448 (6.1758), "0.08" (14)
# p=0.1339 (6.0977), "0.04" (12)
# p=0.1293 (6.0625), "0.10" (15)
# p=0.0924 (5.7266), "0.02" (11)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample4_-0.15_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: -0.3
# WARNING: offset_sec=-0.3 is outside the trained grid: tensor([-0.2000, -0.1800, -0.1600, -0.1400, -0.1200, -0.1000, -0.0800, -0.0600,
#         -0.0400, -0.0200,  0.0000,  0.0200,  0.0400,  0.0600,  0.0800,  0.1000,
#          0.1200,  0.1400,  0.1600,  0.1800,  0.2000])
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: -0.3 0.5
# here4:-0.3
# nivi: 0.2
# nivi: 0.48
# nivi: 0.2, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.2
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): -0.20 (0)
# Prediction Results:
# p=0.2263 (6.9688), "-0.06" (7)
# p=0.2101 (6.8945), "-0.04" (8)
# p=0.1525 (6.5742), "-0.08" (6)
# p=0.0958 (6.1094), "-0.02" (9)
# p=0.0661 (5.7383), "-0.10" (5)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample4_-0.1_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: -0.2
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: -0.2 0.5
# here4:-0.2
# nivi: 0.3
# nivi: 0.48
# nivi: 0.3, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.3
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): -0.20 (0)
# Prediction Results:
# p=0.1897 (6.5117), "-0.04" (8)
# p=0.1687 (6.3945), "-0.06" (7)
# p=0.1293 (6.1289), "-0.02" (9)
# p=0.1205 (6.0586), "-0.08" (6)
# p=0.0690 (5.5000), "-0.10" (5)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample4_0.03_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.06
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.06 0.5
# here4:0.06
# nivi: 0.56
# nivi: 0.48
# nivi: 0.56, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.56
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.06 (13)
# Prediction Results:
# p=0.1737 (6.0039), "-0.02" (9)
# p=0.1691 (5.9766), "0.00" (10)
# p=0.1332 (5.7383), "-0.04" (8)
# p=0.1218 (5.6484), "0.02" (11)
# p=0.0659 (5.0352), "-0.06" (7)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample4_0.08_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.16
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.16 0.5
# here4:0.16
# nivi: 0.66
# nivi: 0.48
# nivi: 0.66, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.66
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.16 (18)
# Prediction Results:
# p=0.2094 (6.3398), "0.02" (11)
# p=0.2085 (6.3359), "0.04" (12)
# p=0.1427 (5.9570), "0.00" (10)
# p=0.1305 (5.8672), "0.06" (13)
# p=0.0789 (5.3633), "-0.02" (9)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample4_0.15_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.3
# WARNING: offset_sec=0.3 is outside the trained grid: tensor([-0.2000, -0.1800, -0.1600, -0.1400, -0.1200, -0.1000, -0.0800, -0.0600,
#         -0.0400, -0.0200,  0.0000,  0.0200,  0.0400,  0.0600,  0.0800,  0.1000,
#          0.1200,  0.1400,  0.1600,  0.1800,  0.2000])
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.3 0.5
# here4:0.3
# nivi: 0.8
# nivi: 0.48
# nivi: 0.8, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.8
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.20 (20)
# Prediction Results:
# p=0.2048 (6.1250), "0.04" (12)
# p=0.1985 (6.0938), "0.06" (13)
# p=0.1287 (5.6602), "0.02" (11)
# p=0.1247 (5.6289), "0.08" (14)
# p=0.0898 (5.3008), "0.10" (15)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample5_-0.15_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: -0.3
# WARNING: offset_sec=-0.3 is outside the trained grid: tensor([-0.2000, -0.1800, -0.1600, -0.1400, -0.1200, -0.1000, -0.0800, -0.0600,
#         -0.0400, -0.0200,  0.0000,  0.0200,  0.0400,  0.0600,  0.0800,  0.1000,
#          0.1200,  0.1400,  0.1600,  0.1800,  0.2000])
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: -0.3 0.5
# here4:-0.3
# nivi: 0.2
# nivi: 0.48
# nivi: 0.2, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.2
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): -0.20 (0)
# Prediction Results:
# p=0.1418 (6.2305), "-0.14" (3)
# p=0.1354 (6.1836), "-0.12" (4)
# p=0.1233 (6.0898), "-0.08" (6)
# p=0.1109 (5.9844), "-0.10" (5)
# p=0.1063 (5.9414), "-0.20" (0)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample5_-0.1_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: -0.2
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: -0.2 0.5
# here4:-0.2
# nivi: 0.3
# nivi: 0.48
# nivi: 0.3, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.3
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): -0.20 (0)
# Prediction Results:
# p=0.2489 (6.9922), "-0.02" (9)
# p=0.2104 (6.8242), "0.00" (10)
# p=0.1786 (6.6602), "-0.04" (8)
# p=0.1266 (6.3164), "0.02" (11)
# p=0.0759 (5.8047), "-0.06" (7)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample5_0.03_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.06
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.06 0.5
# here4:0.06
# nivi: 0.56
# nivi: 0.48
# nivi: 0.56, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.56
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.06 (13)
# Prediction Results:
# p=0.1462 (6.8281), "0.06" (13)
# p=0.1400 (6.7852), "0.10" (15)
# p=0.1321 (6.7266), "0.04" (12)
# p=0.1217 (6.6445), "0.08" (14)
# p=0.1029 (6.4766), "0.12" (16)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample5_0.08_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.16
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.16 0.5
# here4:0.16
# nivi: 0.66
# nivi: 0.48
# nivi: 0.66, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.66
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.16 (18)
# Prediction Results:
# p=0.1686 (7.1836), "0.14" (17)
# p=0.1344 (6.9570), "0.12" (16)
# p=0.1283 (6.9102), "0.10" (15)
# p=0.1159 (6.8086), "0.06" (13)
# p=0.1154 (6.8047), "0.08" (14)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample5_0.15_4s.mp4
# Reencoding. vfps: 30.0 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: 0.3
# WARNING: offset_sec=0.3 is outside the trained grid: tensor([-0.2000, -0.1800, -0.1600, -0.1400, -0.1200, -0.1000, -0.0800, -0.0600,
#         -0.0400, -0.0200,  0.0000,  0.0200,  0.0400,  0.0600,  0.0800,  0.1000,
#          0.1200,  0.1400,  0.1600,  0.1800,  0.2000])
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.3 0.5
# here4:0.3
# nivi: 0.8
# nivi: 0.48
# nivi: 0.8, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.8
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.20 (20)
# Prediction Results:
# p=0.3052 (7.8242), "0.06" (13)
# p=0.2114 (7.4570), "0.08" (14)
# p=0.2107 (7.4531), "0.04" (12)
# p=0.0775 (6.4531), "0.10" (15)
# p=0.0554 (6.1172), "0.02" (11)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample6_-0.15_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: -0.3
# WARNING: offset_sec=-0.3 is outside the trained grid: tensor([-0.2000, -0.1800, -0.1600, -0.1400, -0.1200, -0.1000, -0.0800, -0.0600,
#         -0.0400, -0.0200,  0.0000,  0.0200,  0.0400,  0.0600,  0.0800,  0.1000,
#          0.1200,  0.1400,  0.1600,  0.1800,  0.2000])
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: -0.3 0.5
# here4:-0.3
# nivi: 0.2
# nivi: 0.48
# nivi: 0.2, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.2
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): -0.20 (0)
# Prediction Results:
# p=0.5986 (10.0859), "-0.20" (0)
# p=0.2827 (9.3359), "-0.18" (1)
# p=0.0693 (7.9297), "-0.16" (2)
# p=0.0200 (6.6875), "-0.14" (3)
# p=0.0074 (5.6875), "-0.04" (8)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample6_-0.1_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: -0.2
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: -0.2 0.5
# here4:-0.2
# nivi: 0.3
# nivi: 0.48
# nivi: 0.3, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.3
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): -0.20 (0)
# Prediction Results:
# p=0.3442 (8.0078), "-0.20" (0)
# p=0.2598 (7.7266), "-0.18" (1)
# p=0.1062 (6.8320), "-0.16" (2)
# p=0.0657 (6.3516), "-0.02" (9)
# p=0.0582 (6.2305), "-0.14" (3)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample6_0.03_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.06
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.06 0.5
# here4:0.06
# nivi: 0.56
# nivi: 0.48
# nivi: 0.56, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.56
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.06 (13)
# Prediction Results:
# p=0.2581 (7.0078), "-0.18" (1)
# p=0.2444 (6.9531), "-0.16" (2)
# p=0.2107 (6.8047), "-0.14" (3)
# p=0.0594 (5.5391), "0.02" (11)
# p=0.0535 (5.4336), "-0.12" (4)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample6_0.08_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.16
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.16 0.5
# here4:0.16
# nivi: 0.66
# nivi: 0.48
# nivi: 0.66, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.66
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.16 (18)
# Prediction Results:
# p=0.3789 (7.9375), "0.04" (12)
# p=0.2771 (7.6250), "0.02" (11)
# p=0.2192 (7.3906), "0.06" (13)
# p=0.0456 (5.8203), "0.00" (10)
# p=0.0401 (5.6914), "0.08" (14)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c16_sample6_0.15_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (1080, 1920) -> min(H, W)=256
# offset_sec: 0.3
# WARNING: offset_sec=0.3 is outside the trained grid: tensor([-0.2000, -0.1800, -0.1600, -0.1400, -0.1200, -0.1000, -0.0800, -0.0600,
#         -0.0400, -0.0200,  0.0000,  0.0200,  0.0400,  0.0600,  0.0800,  0.1000,
#          0.1200,  0.1400,  0.1600,  0.1800,  0.2000])
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: 0.3 0.5
# here4:0.3
# nivi: 0.8
# nivi: 0.48
# nivi: 0.8, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.8
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): 0.20 (20)
# Prediction Results:
# p=0.4875 (8.4062), "0.06" (13)
# p=0.2725 (7.8242), "0.04" (12)
# p=0.1459 (7.1992), "0.08" (14)
# p=0.0483 (6.0938), "0.02" (11)
# p=0.0207 (5.2461), "0.10" (15)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c19_sample1_-0.15_4s.mp4
# Reencoding. vfps: 29.97 -> 25; afps: 44100 -> 16000; (720, 1280) -> min(H, W)=256
# offset_sec: -0.3
# WARNING: offset_sec=-0.3 is outside the trained grid: tensor([-0.2000, -0.1800, -0.1600, -0.1400, -0.1200, -0.1000, -0.0800, -0.0600,
#         -0.0400, -0.0200,  0.0000,  0.0200,  0.0400,  0.0600,  0.0800,  0.1000,
#          0.1200,  0.1400,  0.1600,  0.1800,  0.2000])
# Current Working Directory (full path): /home/gnivedita/Synchformer
# here1: True True
# here2
# nivi1: -0.3 0.5
# here4:-0.3
# nivi: 0.2
# nivi: 0.48
# nivi: 0.2, frames2sec(a_crop_len_frames, a_fps)=5.0, frames2sec(a_end_i, a_fps)=5.2
# nivi: 0.48, frames2sec(v_crop_len_frames, v_fps)=5.0, frames2sec(v_end_i, v_fps)=5.48
# Ground Truth offset (sec): -0.20 (0)
# Prediction Results:
# p=0.4629 (8.6094), "-0.20" (0)
# p=0.2742 (8.0859), "-0.18" (1)
# p=0.1348 (7.3750), "-0.16" (2)
# p=0.0753 (6.7930), "-0.14" (3)
# p=0.0316 (5.9258), "-0.12" (4)
#
# Using video: /home/gnivedita/Wav2Lip/videos/set2/set2_c19_sample1_-0.1_4s.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 7
#       4 with open("./result.csv", 'a') as f:
#       5     f.write(f"{vid_path.split('/')[-1][:-4]},{v_start_i_sec},")
# ----> 7 v, _, info = torchvision.io.read_video(vid_path, pts_unit='sec')
#       8 _, H, W, _ = v.shape
#       9 if info['video_fps'] != vfps or info['audio_fps'] != afps or min(H, W) != in_size:
#
# File ~/anaconda3/envs/synchformer/lib/python3.8/site-packages/torchvision/io/video.py:296, in read_video(filename, start_pts, end_pts, pts_unit, output_format)
#     294     audio_timebase = container.streams.audio[0].time_base
#     295 if container.streams.video:
# --> 296     video_frames = _read_from_stream(
#     297         container,
#     298         start_pts,
#     299         end_pts,
#     300         pts_unit,
#     301         container.streams.video[0],
#     302         {"video": 0},
#     303     )
#     304     video_fps = container.streams.video[0].average_rate
#     305     # guard against potentially corrupted files
#
# File ~/anaconda3/envs/synchformer/lib/python3.8/site-packages/torchvision/io/video.py:198, in _read_from_stream(container, start_offset, end_offset, pts_unit, stream, stream_name)
#     196 buffer_count = 0
#     197 try:
# --> 198     for _idx, frame in enumerate(container.decode(**stream_name)):
#     199         frames[frame.pts] = frame
#     200         if frame.pts >= end_offset:
#
# KeyboardInterrupt:

# %%
# !pip freeze
